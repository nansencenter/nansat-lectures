# %% [markdown]
# # Nansat: First Steps

# %% [markdown]
# ### Copy sample data

# %%
import os
import shutil
import nansat
idir = os.path.join(os.path.dirname(nansat.__file__), 'tests', 'data/')

# %% [markdown]
# ### Open file with Nansat

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


from nansat import Nansat
n = Nansat(idir+'gcps.tif')

# %% [markdown]
# ### Read information ABOUT the data (METADATA)

# %%
print n
# Out:
# ----------------------------------------
# /home/vagrant/miniconda/lib/python2.7/site-packages/nansat/tests/data/gcps.tif
# ----------------------------------------
# Mapper: generic
# ----------------------------------------
# Band : 1 L_645
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/vagrant/miniconda/lib/python2.7/site-packages/nansat/tests/data/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 1
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_645
# Band : 2 L_555
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/vagrant/miniconda/lib/python2.7/site-packages/nansat/tests/data/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 2
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_555
# Band : 3 L_469
#   units: W m-2 m-1 sr-1
#   colormap: jet
#   short_name: nLw
#   dataType: 1
#   long_name: Upward spectral radiance
#   standard_name: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   SourceFilename: /home/vagrant/miniconda/lib/python2.7/site-packages/nansat/tests/data/gcps.tif
#   time: 2011-08-15 10:05:00
#   minmax: 0.000 500
#   SourceBand: 3
#   wkv: surface_upwelling_spectral_radiance_in_air_emerging_from_sea_water
#   name: L_469
# ----------------------------------------
# Domain:[200 x 200]
# ----------------------------------------
# Projection:
# GEOGCS["WGS 84",
#     DATUM["WGS_1984",
#         SPHEROID["WGS 84",6378137,298.257223563]],
#     PRIMEM["Greenwich",0],
#     UNIT["degree",0.0174532925199433]]
# ----------------------------------------
# Corners (lon, lat):
# 	 ( 28.25,  71.54)  ( 30.87,  71.17)
# 	 ( 27.14,  70.72)  ( 29.68,  70.35)

# %% [markdown]
# ### Read the actual DATA

# %%
b1 = n[1]

# %% [markdown]
# ### Check what kind of data we have

# %%
# %whos
plt.imshow(b1);plt.colorbar()
plt.show()
# Out:
# Variable   Type       Data/Info
# -------------------------------
# Nansat     type       <class 'nansat.nansat.Nansat'>
# b1         ndarray    200x200: 40000 elems, type `uint8`, 40000 bytes
# idir       str        /home/vagrant/miniconda/l<...>ckages/nansat/tests/data/
# n          Nansat     -------------------------<...>0.72)  ( 29.68,  70.35)\n
# nansat     module     <module 'nansat' from '/h<...>ges/nansat/__init__.pyc'>
# os         module     <module 'os' from '/home/<...>da/lib/python2.7/os.pyc'>
# plt        module     <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# shutil     module     <module 'shutil' from '/h<...>ib/python2.7/shutil.pyc'>

# %% [markdown]
# ### Find where the image is taken

# %%
n.write_map('map.png', pltshow=True)

# %% [markdown]
# # Nansat: Overview

# %% [markdown]
# The NANSAT package contains several classes:
#
# * Nansat    - open and read satellite data
# * Domain    - define grid for the region of interest
# * Figure    - create raster images (PNG, TIF)
# * NSR       - define spatial reference (SR)
# * Nansatmap - make maps which combine raster and vector data (image, contours)
# * Mosaic    - colocate and average several images
