# %%
from nansat import Nansat
# open file
n = Nansat('MYD02HKM.A2011229.1005.005.2011230152517.hdf')
# crop to region of interest
n.crop(600, 2400, 1000, 1000)
# create RGB image from red green and blue channels
f=n.write_figure('test_rgb.png', ['L_858', 'L_555', 'L_469'],
               clim='hist', ratio=0.95)
# Out:
# WARNING: Using the default (non-CF) Udunits database

# %%
from IPython.core.display import Image
Image(filename='test_rgb.png')
